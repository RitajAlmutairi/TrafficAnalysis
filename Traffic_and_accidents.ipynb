# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
df = pd.read_csv('dataset path')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
#Drop columns with high number of missing values
df.drop(columns = ['Work_of_casuality', 'Fitness_of_casuality','Service_year_of_vehicle','Defect_of_vehicle'], inplace = True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level              741
# Vehicle_driver_relation        579
# Driving_experience             829
# Type_of_vehicle                950
# Owner_of_vehicle               482
# Area_accident_occured          239
# Lanes_or_Medians               385
# Road_allignment                142
# Types_of_Junction              887
# Road_surface_type              172
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision              155
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               308
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# Pedestrian_movement              0
# Cause_of_accident                0
# ...

# %%
df.Type_of_collision
# Out:
# 0        Collision with roadside-parked vehicles
# 1                 Vehicle with vehicle collision
# 2                Collision with roadside objects
# 3                 Vehicle with vehicle collision
# 4                 Vehicle with vehicle collision
#                           ...
# 12311             Vehicle with vehicle collision
# 12312             Vehicle with vehicle collision
# 12313             Vehicle with vehicle collision
# 12314             Vehicle with vehicle collision
# 12315             Vehicle with vehicle collision
# Name: Type_of_collision, Length: 12316, dtype: object

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# ...

# %%
df.fillna(df.Type_of_collision.mode()[0], inplace = True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.Driving_experience.value_counts()
# Out:
# Driving_experience
# 5-10yr                            3363
# 2-5yr                             2613
# Above 10yr                        2262
# 1-2yr                             1756
# Below 1yr                         1342
# Vehicle with vehicle collision     829
# No Licence                         118
# unknown                             33
# Name: count, dtype: int64

# %%
df.Driving_experience.isnull().sum()
# Out:
# 0

# %%
df.Vehicle_driver_relation.unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', 'Vehicle with vehicle collision',
#        'Other'], dtype=object)

# %%
df.Vehicle_driver_relation.unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', 'Vehicle with vehicle collision',
#        'Other'], dtype=object)

# %%
df.Vehicle_driver_relation.value_counts()
# Out:
# Vehicle_driver_relation
# Employee                          9627
# Owner                             1973
# Vehicle with vehicle collision     579
# Other                              123
# Unknown                             14
# Name: count, dtype: int64

# %%
df.Vehicle_driver_relation.mode()
# Out:
# 0    Employee
# Name: Vehicle_driver_relation, dtype: object

# %%
df.fillna(df.Vehicle_driver_relation.mode()[0], inplace = True)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df['Vehicle_driver_relation'].isnull().sum()
# Out:
# 0

# %%
#Check duplicated
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df.query('Casualty_class == "na"')
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 4       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 10     14:40:00    Saturday              18-30          Male
# ...         ...         ...                ...           ...
# 12307  17:10:00      Friday              31-50          Male
# 12308  17:10:00      Friday              18-30          Male
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12314  13:55:00      Sunday              18-30        Female
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df['Casualty_class']= df['Casualty_class'].replace('na',df['Casualty_class'].mode()[0])
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.drop(columns ='Type_of_vehicle', inplace = True )
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Owner_of_vehicle               object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# Pedestrian_movement            object
# ...

# %%
df['Age_band_of_driver']= df['Age_band_of_driver'].replace('Unknown',df['Age_band_of_driver'].mode()[0])
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.query('Age_band_of_driver == "Unknown"')
# Out:
# Empty DataFrame
# Columns: [Time, Day_of_week, Age_band_of_driver, Sex_of_driver, Educational_level, Vehicle_driver_relation, Driving_experience, Owner_of_vehicle, Area_accident_occured, Lanes_or_Medians, Road_allignment, Types_of_Junction, Road_surface_type, Road_surface_conditions, Light_conditions, Weather_conditions, Type_of_collision, Number_of_vehicles_involved, Number_of_casualties, Vehicle_movement, Casualty_class, Sex_of_casualty, Age_band_of_casualty, Casualty_severity, Pedestrian_movement, Cause_of_accident, Accident_severity]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.Casualty_class.unique()
# Out:
# array(['Driver or rider', 'Pedestrian', 'Passenger'], dtype=object)

# %%
Casualty_class_dict = {'Driver': 1, 'Passenger': 2, 'Pedestrian': 3}

df['Casualty_class'] = df['Casualty_class'].map(Casualty_class_dict)
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.Sex_of_casualty.unique()
# Out:
# array(['na', 'Male', 'Female'], dtype=object)

# %%
df['Sex_of_casualty']= df['Sex_of_casualty'].replace('na',df['Sex_of_casualty'].mode()[0])
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday              18-30          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.Number_of_vehicles_involved.unique()
# Out:
# array([2, 1, 3, 6, 4, 7])

# %%
df.Number_of_casualties.value_counts()
# Out:
# Number_of_casualties
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: count, dtype: int64

# %%
df.Number_of_casualties.unique()
# Out:
# array([2, 1, 3, 4, 6, 5, 8, 7])

# %%
df.Number_of_casualties.value_counts()
# Out:
# Number_of_casualties
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: count, dtype: int64

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                            object
# Day_of_week                     object
# Age_band_of_driver              object
# Sex_of_driver                   object
# Educational_level               object
# Vehicle_driver_relation         object
# Driving_experience              object
# Owner_of_vehicle                object
# Area_accident_occured           object
# Lanes_or_Medians                object
# Road_allignment                 object
# Types_of_Junction               object
# Road_surface_type               object
# Road_surface_conditions         object
# Light_conditions                object
# Weather_conditions              object
# Type_of_collision               object
# Number_of_vehicles_involved      int64
# Number_of_casualties             int64
# Vehicle_movement                object
# Casualty_class                 float64
# Sex_of_casualty                 object
# Age_band_of_casualty            object
# Casualty_severity               object
# ...

# %%
sex_dict = {'Male': 1, 'Female': 2}

df['Sex_of_driver'] = df['Sex_of_driver'].map(sex_dict)
df
# Out:
#            Time Day_of_week Age_band_of_driver  Sex_of_driver  \
# 0      17:02:00      Monday              18-30            1.0
# 1      17:02:00      Monday              31-50            1.0
# 2      17:02:00      Monday              18-30            1.0
# 3       1:06:00      Sunday              18-30            1.0
# 4       1:06:00      Sunday              18-30            1.0
# ...         ...         ...                ...            ...
# 12311  16:15:00   Wednesday              31-50            1.0
# 12312  18:00:00      Sunday              18-30            1.0
# 12313  13:55:00      Sunday            Over 51            1.0
# 12314  13:55:00      Sunday              18-30            2.0
# 12315  13:55:00      Sunday              18-30            1.0
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.Sex_of_driver.convert_dtypes(int)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 12311    1
# 12312    1
# 12313    1
# 12314    2
# 12315    1
# Name: Sex_of_driver, Length: 12316, dtype: Int64

# %%
df.query('Sex_of_driver == "nan"')
# Out:
# Empty DataFrame
# Columns: [Time, Day_of_week, Age_band_of_driver, Sex_of_driver, Educational_level, Vehicle_driver_relation, Driving_experience, Owner_of_vehicle, Area_accident_occured, Lanes_or_Medians, Road_allignment, Types_of_Junction, Road_surface_type, Road_surface_conditions, Light_conditions, Weather_conditions, Type_of_collision, Number_of_vehicles_involved, Number_of_casualties, Vehicle_movement, Casualty_class, Sex_of_casualty, Age_band_of_casualty, Casualty_severity, Pedestrian_movement, Cause_of_accident, Accident_severity]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.Age_band_of_driver.unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51'], dtype=object)

# %%
Age_band_dic = { 'Under 18': 'Teenagers',
                '18-30': 'Middel Age',
                '31-50': 'Old',
                'Over 51': 'Very Old'}

df['Age_band_of_driver'] = df['Age_band_of_driver'].map(Age_band_dic)
df
# Out:
#            Time Day_of_week Age_band_of_driver  Sex_of_driver  \
# 0      17:02:00      Monday         Middel Age            1.0
# 1      17:02:00      Monday                Old            1.0
# 2      17:02:00      Monday         Middel Age            1.0
# 3       1:06:00      Sunday         Middel Age            1.0
# 4       1:06:00      Sunday         Middel Age            1.0
# ...         ...         ...                ...            ...
# 12311  16:15:00   Wednesday                Old            1.0
# 12312  18:00:00      Sunday         Middel Age            1.0
# 12313  13:55:00      Sunday           Very Old            1.0
# 12314  13:55:00      Sunday         Middel Age            2.0
# 12315  13:55:00      Sunday         Middel Age            1.0
#
#                     Educational_level Vehicle_driver_relation  \
# 0                   Above high school                Employee
# 1                  Junior high school                Employee
# ...

# %%
df.Educational_level.unique()
# Out:
# array(['Above high school', 'Junior high school',
#        'Vehicle with vehicle collision', 'Elementary school',
#        'High school', 'Unknown', 'Illiterate', 'Writing & reading'],
#       dtype=object)

# %%
df.query('Educational_level == "Vehicle with vehicle collision"')
# Out:
#            Time Day_of_week Age_band_of_driver  Sex_of_driver  \
# 5      14:15:00      Friday                Old            1.0
# 24     18:36:00   Wednesday         Middel Age            1.0
# 28     12:25:00     Tuesday           Very Old            NaN
# 29     12:25:00     Tuesday         Middel Age            1.0
# 38     20:30:00      Friday           Very Old            1.0
# ...         ...         ...                ...            ...
# 12285  17:50:00    Saturday                Old            1.0
# 12291  16:26:00     Tuesday           Very Old            1.0
# 12294  13:54:00    Saturday         Middel Age            1.0
# 12310   9:05:00      Friday         Middel Age            1.0
# 12311  16:15:00   Wednesday                Old            1.0
#
#                     Educational_level         Vehicle_driver_relation  \
# 5      Vehicle with vehicle collision                         Unknown
# 24     Vehicle with vehicle collision                         Unknown
# ...

# %%
#I assumed the vehicle involved in the collision was incorrectly recorded during data entry
df = df[df['Educational_level'] != "Vehicle with vehicle collision"]
df
# Out:
#            Time Day_of_week Age_band_of_driver  Sex_of_driver  \
# 0      17:02:00      Monday         Middel Age            1.0
# 1      17:02:00      Monday                Old            1.0
# 2      17:02:00      Monday         Middel Age            1.0
# 3       1:06:00      Sunday         Middel Age            1.0
# 4       1:06:00      Sunday         Middel Age            1.0
# ...         ...         ...                ...            ...
# 12309   9:05:00      Friday                Old            2.0
# 12312  18:00:00      Sunday         Middel Age            1.0
# 12313  13:55:00      Sunday           Very Old            1.0
# 12314  13:55:00      Sunday         Middel Age            2.0
# 12315  13:55:00      Sunday         Middel Age            1.0
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.query('Educational_level == "Vehicle with vehicle collision"')
# Out:
# Empty DataFrame
# Columns: [Time, Day_of_week, Age_band_of_driver, Sex_of_driver, Educational_level, Vehicle_driver_relation, Driving_experience, Owner_of_vehicle, Area_accident_occured, Lanes_or_Medians, Road_allignment, Types_of_Junction, Road_surface_type, Road_surface_conditions, Light_conditions, Weather_conditions, Type_of_collision, Number_of_vehicles_involved, Number_of_casualties, Vehicle_movement, Casualty_class, Sex_of_casualty, Age_band_of_casualty, Casualty_severity, Pedestrian_movement, Cause_of_accident, Accident_severity]
# Index: []
#
# [0 rows x 27 columns]

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# <ipython-input-212-1bfd8981fe14>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])
# <ipython-input-212-1bfd8981fe14>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df.Number_of_vehicles_involved.convert_dtypes(int)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 12309    2
# 12312    2
# 12313    1
# 12314    2
# 12315    2
# Name: Number_of_vehicles_involved, Length: 11575, dtype: Int64

# %%
df.Number_of_casualties.convert_dtypes(int)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 12309    2
# 12312    1
# 12313    1
# 12314    1
# 12315    1
# Name: Number_of_casualties, Length: 11575, dtype: Int64

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#                                 Time  Sex_of_driver  \
# count                          11575   11409.000000
# mean   2024-07-29 14:17:08.853563648       1.058112
# min              2024-07-29 00:01:00       1.000000
# 25%              2024-07-29 10:30:00       1.000000
# 50%              2024-07-29 15:10:00       1.000000
# 75%              2024-07-29 18:10:00       1.000000
# max              2024-07-29 23:59:00       2.000000
# std                              NaN       0.233965
#
#        Number_of_vehicles_involved  Number_of_casualties  Casualty_class
# count                 11575.000000          11575.000000     2754.000000
# mean                      2.041296              1.547991        2.558097
# min                       1.000000              1.000000        2.000000
# 25%                       2.000000              1.000000        2.000000
# 50%                       2.000000              1.000000        3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11575 entries, 0 to 12315
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         11575 non-null  datetime64[ns]
#  1   Day_of_week                  11575 non-null  object
#  2   Age_band_of_driver           11575 non-null  object
#  3   Sex_of_driver                11409 non-null  float64
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11575 non-null  object
#  6   Driving_experience           11575 non-null  object
#  7   Owner_of_vehicle             11575 non-null  object
#  8   Area_accident_occured        11575 non-null  object
#  9   Lanes_or_Medians             11575 non-null  object
#  10  Road_allignment              11575 non-null  object
#  11  Types_of_Junction            11575 non-null  object
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.corr(numeric_only=True)
# Out:
#                              Sex_of_driver  Number_of_vehicles_involved  \
# Sex_of_driver                     1.000000                     0.035768
# Number_of_vehicles_involved       0.035768                     1.000000
# Number_of_casualties             -0.057078                     0.214447
# Casualty_class                   -0.012243                    -0.026214
#
#                              Number_of_casualties  Casualty_class
# Sex_of_driver                           -0.057078       -0.012243
# Number_of_vehicles_involved              0.214447       -0.026214
# Number_of_casualties                     1.000000       -0.038878
# Casualty_class                          -0.038878        1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.gifigsize=(20,20)
sns.heatmap(df.corr(numeric_only=True),annot = True)
plt.xticks(rotation=60);

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.histplot(df, x = 'Age_band_of_driver');
plt.title("Age Band of Driver Count")
# Out:
# Text(0.5, 1.0, 'Age Band of Driver Count')

# %% [markdown]
# - Most drivers's Age group are in middle age (between 18 -31)

# %%
plt.figure(figsize=(10,10)  )
sns.histplot(df, x = 'Vehicle_driver_relation');
plt.title("Vehicle Driver Relation Count")
# Out:
# Text(0.5, 1.0, 'Vehicle Driver Relation Count')

# %% [markdown]
# - Most drivers are employee then car owners

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.dtypes
# Out:
# Time                           datetime64[ns]
# Day_of_week                            object
# Age_band_of_driver                     object
# Sex_of_driver                         float64
# Educational_level                      object
# Vehicle_driver_relation                object
# Driving_experience                     object
# Owner_of_vehicle                       object
# Area_accident_occured                  object
# Lanes_or_Medians                       object
# Road_allignment                        object
# Types_of_Junction                      object
# Road_surface_type                      object
# Road_surface_conditions                object
# Light_conditions                       object
# Weather_conditions                     object
# Type_of_collision                      object
# Number_of_vehicles_involved             int64
# Number_of_casualties                    int64
# Vehicle_movement                       object
# ...

# %%
sns.boxplot(x="Age_band_of_driver", y="Number_of_casualties", hue="Sex_of_driver", data=df);

# %% [markdown]
# #### The middle age and Old age has higher Number of casualties

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.lineplot(x = 'Number_of_vehicles_involved', y = 'Number_of_casualties', data = df);

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
#  - Most drivers are middle age
#  - Most middle age drivers are male , and most teenagers drivers are female
#  - If the number of vehicles involved = 4 --> Highest Number of casualties
#  - Most drivers are employee
